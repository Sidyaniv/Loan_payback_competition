# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, RocCurveDisplay
from IPython.display import display

# from sklearn.model_selection import

# %% [markdown]
# ### Загрузка, разбиение данных

# %%
root_path = os.curdir
data_path = os.path.join(root_path, 'data')

path_to_dataset = os.path.join(data_path, 'loan_dataset_20000.csv')

# %%
df = pd.read_csv(path_to_dataset)

X, y = df.iloc[:, :-1], df.iloc[:, -1]

num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_cols = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()

display(num_cols, cat_cols)
# Out:
# ['age',
#  'annual_income',
#  'monthly_income',
#  'debt_to_income_ratio',
#  'credit_score',
#  'loan_amount',
#  'interest_rate',
#  'loan_term',
#  'installment',
#  'num_of_open_accounts',
#  'total_credit_limit',
#  'current_balance',
#  'delinquency_history',
#  'public_records',
#  'num_of_delinquencies',
#  'loan_paid_back']
# ['gender',
#  'marital_status',
#  'education_level',
#  'employment_status',
#  'loan_purpose',
#  'grade_subgrade']

# %%
X.drop(columns=['annual_income'], inplace=True) #'annual_income'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = X.corr(numeric_only=True)

plt.figure(figsize=(12, 10)) 
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.show()

# TODO: Убрать сильные корреляции между признаками (
# - оставить имющиеся признаки и добавить новые (например отношение monthly_income/total_credit_limit )
# - Посмотреть, интерпетируемы ли значения полученных коэффициентов
# Если пропадёт логика в знаках коэффициентов, значит надо удалять корреляции

# %%
# submission.head()
test_data.head()
train_data.head()
# Out:
#     annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# id
# 0        29367.99                 0.084           736      2528.42
# 1        22108.02                 0.166           636      4593.10
# 2        49566.20                 0.097           694     17005.15
# 3        46858.25                 0.065           533      4682.48
# 4        25496.70                 0.053           665     12184.43
#
#     interest_rate  gender marital_status education_level employment_status  \
# id
# 0           13.67  Female         Single     High School     Self-employed
# 1           12.92    Male        Married        Master's          Employed
# 2            9.76    Male         Single     High School          Employed
# 3           16.10  Female         Single     High School          Employed
# 4           10.21    Male        Married     High School          Employed
#
#           loan_purpose grade_subgrade  loan_paid_back
# id
# ...

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train_full, 
                                                  y_train_full, 
                                                  test_size=0.25,
                                                  random_state=7,
                                                  )

# %% [markdown]
# ### Preprocessing
# ---
# #### Filling NaN

# %%
X_train, y_train = 
# X_val, y_val =

# %% [markdown]
# ### Train
# ---
# #### Logistic Regression

# %%
model_log_reg = LogisticRegression(penalty='elasticnet',
                                   C=1,
                                   random_state=7,
                                   solver='saga',
                                   max_iter=1000,
                                   l1_ratio=0.2
                                   )

model_log_reg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_47315/1072385916.py in ?()
#       5                                    max_iter=1000,
#       6                                    l1_ratio=0.2
#       7                                    )
#       8
# ----> 9 model_log_reg.fit(X_train, y_train)
#
# ~/Desktop/projects/kaggle_competitions/loan_payback/.venv/lib/python3.13/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# ~/Desktop/projects/kaggle_competitions/loan_payback/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py in ?(self, X, y, sample_weight)
# ...
